# %%
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 39.9 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd

# --- CONFIGURATION ---
TSV_FILE = "split.tsv" # Path to tsv containng information about split/train for images. All images not listed in the tsv are considered to be train
IMAGE_FOLDER = "./images/"  # Path to image folder


# 1. Load the TSV file
print("Reading TSV file...")
df = pd.read_csv(TSV_FILE, sep="\t", index_col="filename")

# Clean up filename tracking (strip any trailing spaces/newlines)
df.index = df.index.astype(str).str.strip()
tsv_filenames = set(df.index)

# 2. Get all images currently inside the folder
if not os.path.exists(IMAGE_FOLDER):
    print(f"Error: Folder '{IMAGE_FOLDER}' not found.")
    exit()

folder_filenames = set(os.listdir(IMAGE_FOLDER))


# 3. Clean up the Image Folder (Remove images missing from TSV)
print("\n--- Step 1: Cleaning Image Folder ---")
images_to_augment = folder_filenames - tsv_filenames

if images_to_augment:
    print(f"Found {len(images_to_augment)} images in folder that are not in the TSV.")
    for img_name in images_to_delete:
        df.loc[img_name] = [None, "train", "brandenburg"]
else:
    print("All folder images have a valid TSV entry. No entries augmented.")

df.to_csv('sample.tsv', sep="\t")

print("\nSynchronization complete! Your TSV and image folder match perfectly.")
# Out:
# Reading TSV file...
#
# --- Step 1: Cleaning Image Folder ---
# Found 495 images in folder that are not in the TSV.
#
# Synchronization complete! Your TSV and image folder match perfectly.
# /tmp/ipykernel_1083541/644901661.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[img_name] = [None, "train", "brandenburg"]
# /tmp/ipykernel_1083541/644901661.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df.loc[img_name] = [None, "train", "brandenburg"]
# ...
